# %%
# Import packages匯入模組
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
# Read data讀取資料
df = pd.read_csv(r'D:\portfo\movies.csv')

# %%
#look at data看看總體資料
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Check NaN 查看有沒有空缺
for col in df.columns:
    missing = df[col].isnull().sum()
    print('{} - {}'.format(col, missing))
# Out:
# name - 0
# rating - 77
# genre - 0
# year - 0
# released - 2
# score - 3
# votes - 3
# director - 0
# writer - 3
# star - 1
# country - 3
# budget - 2171
# gross - 189
# company - 17
# runtime - 4

# %%
#drop rows with NaN 刪除帶有NaN的行列
df = df.dropna(axis = 0)

# %%
#Boxplot to see outliers 箱線圖來看離群值
df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
#Check data types 查看資料的型態
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Check NaN again 再次查看有沒有NaN
for col in df.columns:
    missing = df[col].isnull().sum()
    print('{} - {}'.format(col, missing))
# Out:
# name - 0
# rating - 0
# genre - 0
# year - 0
# released - 0
# score - 0
# votes - 0
# director - 0
# writer - 0
# star - 0
# country - 0
# budget - 0
# gross - 0
# company - 0
# runtime - 0

# %%
#Change data type改變資料的型態
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
# Out:
# <ipython-input-9-f395bf1fbdd7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['budget'] = df['budget'].astype('int64')
# <ipython-input-9-f395bf1fbdd7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gross'] = df['gross'].astype('int64')

# %%
df.dtypes #再次查看資料型態
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
#Create new column for corrected year 增加一個新欄位來放修正的年份
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)
# Out:
# <ipython-input-11-69be744d07b4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

# %%
df.sort_values(by = ['gross'], inplace = False, ascending = False) #以總票房排序
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
#Check for duplicates 查看是否有重複項目
boolean = df.duplicated(subset=['name','yearcorrect','director']).any()
boolean
# Out:
# False

# %%
#Top 10 Company 10大票房電影公司
CompanyGross = df.groupby('company')[["gross"]].sum()
TopCompanyGross = CompanyGross.sort_values('gross', ascending = False)[:10]
TopCompanyGross
# Out:
#                              gross
# company
# Warner Bros.           54610959970
# Universal Pictures     51241105418
# Columbia Pictures      42356430218
# Paramount Pictures     40021704691
# Twentieth Century Fox  39542573303
# Walt Disney Pictures   35833650748
# New Line Cinema        19612851164
# Marvel Studios         15065592411
# DreamWorks Animation   11873612858
# Dreamworks Pictures    11593807697

# %%
#Scatter plot for Budget vs Gross 成本vs票房散布圖
plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget vs Gross')
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.show()

# %%
#Seaborn version to show correlation 圖表顯示相關性
sns.regplot(x = df['budget'], y = df['gross'], data = df,scatter_kws={"color": "blue"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Show Correlation betweem score and gross 分數以及票房的相關性
sns.regplot(x="score", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='score', ylabel='gross'>

# %%
#correlation 數字相關性
df.corr()
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              yearcorrect
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.268721
# runtime         0.075294
# yearcorrect     1.000000

# %%
#heatmap to show correalation 熱圖來比較
correlation = df.corr()
sns.heatmap(correlation, annot = True)
plt.title('correlation heatmap')
plt.show()

# %%
#Factoring the non-number columns to find correlation 將其他文字數值化以熱圖來顯示相關性
df_factorize = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
sns.heatmap(df_factorize, annot = True)
plt.title("Correlation")
plt.show()

# %%
#Sort the values 排序
unstack = df_factorize.unstack()
sorted_pairs = unstack.sort_values()
print(sorted_pairs)
# Out:
# genre        rating        -0.116507
# rating       genre         -0.116507
# budget       company       -0.053573
# company      budget        -0.053573
# score        votes         -0.041981
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
# find high correlations 顯示最高相關性
high_corr = sorted_pairs[abs(sorted_pairs) > 0.5 ]

print(high_corr)
# Out:
# yearcorrect  company        0.506753
# company      yearcorrect    0.506753
#              name           0.535369
# name         company        0.535369
# company      year           0.537731
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 82, dtype: float64

# %%
#Scatter plor for categorical variable類別資料散布圖
sns.stripplot(x="rating", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='gross'>
